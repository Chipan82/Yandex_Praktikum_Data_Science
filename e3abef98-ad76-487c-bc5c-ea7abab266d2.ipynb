# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Привет еще раз. Спасибо, что доделал работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет, Андрей! Спасибо, что прислал задание:) Поздравляю с первым сданным проектом! Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделал большую работу над проектом. Он выполнен уже на достойном уровне. Однако есть моменты, которые еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге. Если обращение на ты неприемлемо, то прошу сообщить.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках:
#
# <div class="alert alert-success">Успех: Если фон комментария зелёный - всё сделано правильно. Рекомендации укажу таким же цветом;</div>
#
# <div class="alert alert-warning">Совет: Оранжевый - некритичные замечания;</div>
#
# <div class="alert alert-danger">Ошибка: Красный - нужно переделать. </div>
#
# Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта. Свои же комментарии ты можешь обозначать любым заметным способом.
#
# </div>

# %% [markdown]
# # Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Правильно, что есть краткое вступление в работу, описание того, что надо делать. В работе следует приводить информацию о входных данных: какие столбцы есть в таблице, их названия и какую информацию они несут. Так работа выглядит презентабельно. Подробнее смотри методичку по оформлению проектов. Она располагается в Notion в разделе "Как оформлять проект".
#
# </div>

# %% [markdown]
# - Таблица содержит 12 столбцов и 21525 строк c типом данных в скобках:
#      - children — количество детей в семье
#      - days_employed — общий трудовой стаж в днях
#      - dob_years — возраст клиента в годах
#      - education — уровень образования клиента
#      - education_id — идентификатор уровня образования
#      - family_status — семейное положение
#      - family_status_id — идентификатор семейного положения
#      - gender — пол клиента
#      - income_type — тип занятости
#      - debt — имел ли задолженность по возврату кредитов
#      - total_income — ежемесячный доход
#      - purpose — цель получения кредита

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена.
#
# </div>

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Я заметил, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой работы рекомендую перезапускать ноутбук, чтобы убедиться, что все ячейки выполняются корректно.
#
# </div>

# %% [markdown]
# Спасибо! Принял во внимание.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Перезапуск позволяет обнаружить и исправить скрытые в коде ошибки.
#
# </div>

# %%
import pandas as pd
from pymystem3 import Mystem
m = Mystem()

data = pd.read_csv('/datasets/data.csv')
data.head(50)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# 12         0            NaN         65              среднее             1
# 13         0   -1846.641941         54  неоконченное высшее             2
# 14         0   -1844.956182         56               высшее             0
# 15         1    -972.364419         26              среднее             1
# 16         0   -1719.934226         35              среднее             1
# 17         0   -2369.999720         33               высшее             0
# 18         0  400281.136913         53              среднее             1
# 19         0  -10038.818549         48              СРЕДНЕЕ             1
# 20         1   -1311.604166         36              среднее             1
# 21         1    -253.685166         33              среднее             1
# 22         1   -1766.644138         24              среднее             1
# 23         0    -272.981385         21               высшее             0
# 24         1  338551.952911         57              среднее             1
# 25         0  363548.489348         67              среднее             1
# 26         0            NaN         41              среднее             1
# 27         0    -529.191635         28               высшее             0
# 28         1    -717.274324         26               высшее             0
# 29         0            NaN         63              среднее             1
# 30         1  335581.668515         62              среднее             1
# 31         0   -1682.083438         47            начальное             3
# 32         0   -4649.910832         34              СРЕДНЕЕ             1
# 33         0   -1548.637544         48              среднее             1
# 34         0   -4488.067031         35              среднее             1
# 35         0  394021.072184         68              среднее             1
# 36         0    -176.216688         33              среднее             1
# 37         0   -6448.810860         43               ВЫСШЕЕ             0
# 38         0    -597.881827         25               высшее             0
# 39         0    -650.587796         31               высшее             0
# 40         0   -1030.362606         30              среднее             1
# 41         0            NaN         50              среднее             1
# 42         0   -1257.496190         20  неоконченное высшее             2
# 43         0   -4375.681384         43  неоконченное высшее             2
# 44         1   -1362.041728         26              СРЕДНЕЕ             1
# 45         1   -1039.451741         49              среднее             1
# 46         2   -2262.712304         37              среднее             1
# 47         1   -2689.137274         33               высшее             0
# 48         0   -3341.067886         45              среднее             1
# 49         0   -1181.443228         54              среднее             1
#
#             family_status  family_status_id gender  income_type  debt  \
# 0         женат / замужем                 0      F    сотрудник     0
# 1         женат / замужем                 0      F    сотрудник     0
# 2         женат / замужем                 0      M    сотрудник     0
# 3         женат / замужем                 0      M    сотрудник     0
# 4        гражданский брак                 1      F    пенсионер     0
# 5        гражданский брак                 1      M    компаньон     0
# 6         женат / замужем                 0      F    компаньон     0
# 7         женат / замужем                 0      M    сотрудник     0
# 8        гражданский брак                 1      F    сотрудник     0
# 9         женат / замужем                 0      M    сотрудник     0
# 10        женат / замужем                 0      M    компаньон     0
# 11        женат / замужем                 0      F    сотрудник     0
# 12       гражданский брак                 1      M    пенсионер     0
# 13        женат / замужем                 0      F    сотрудник     0
# 14       гражданский брак                 1      F    компаньон     1
# 15        женат / замужем                 0      F    сотрудник     0
# 16        женат / замужем                 0      F    сотрудник     0
# 17       гражданский брак                 1      M    сотрудник     0
# 18         вдовец / вдова                 2      F    пенсионер     0
# 19              в разводе                 3      F    сотрудник     0
# 20        женат / замужем                 0      M    сотрудник     0
# 21       гражданский брак                 1      F    сотрудник     0
# 22       гражданский брак                 1      F    сотрудник     0
# 23       гражданский брак                 1      M    сотрудник     0
# 24  Не женат / не замужем                 4      F    пенсионер     0
# 25        женат / замужем                 0      M    пенсионер     0
# 26        женат / замужем                 0      M  госслужащий     0
# 27        женат / замужем                 0      M    сотрудник     0
# 28        женат / замужем                 0      F    сотрудник     0
# 29  Не женат / не замужем                 4      F    пенсионер     0
# 30        женат / замужем                 0      F    пенсионер     0
# 31        женат / замужем                 0      F    сотрудник     0
# 32       гражданский брак                 1      F    сотрудник     1
# 33        женат / замужем                 0      F    компаньон     0
# 34        женат / замужем                 0      F    сотрудник     0
# 35       гражданский брак                 1      M    пенсионер     0
# 36  Не женат / не замужем                 4      M    сотрудник     0
# 37       гражданский брак                 1      F    компаньон     0
# 38  Не женат / не замужем                 4      M    сотрудник     1
# 39       гражданский брак                 1      F    компаньон     0
# 40  Не женат / не замужем                 4      M    компаньон     0
# 41        женат / замужем                 0      F  госслужащий     0
# 42  Не женат / не замужем                 4      F    сотрудник     0
# 43              в разводе                 3      F    компаньон     0
# 44        женат / замужем                 0      F    сотрудник     0
# 45  Не женат / не замужем                 4      F    сотрудник     0
# 46        женат / замужем                 0      F    компаньон     0
# 47       гражданский брак                 1      M  госслужащий     0
# 48        женат / замужем                 0      F    сотрудник     0
# 49        женат / замужем                 0      F    сотрудник     0
#
#      total_income                                 purpose
# 0   253875.639453                           покупка жилья
# 1   112080.014102                 приобретение автомобиля
# 2   145885.952297                           покупка жилья
# 3   267628.550329              дополнительное образование
# 4   158616.077870                         сыграть свадьбу
# 5   255763.565419                           покупка жилья
# 6   240525.971920                       операции с жильем
# 7   135823.934197                             образование
# 8    95856.832424                   на проведение свадьбы
# 9   144425.938277                 покупка жилья для семьи
# 10  113943.491460                    покупка недвижимости
# 11   77069.234271       покупка коммерческой недвижимости
# 12            NaN                         сыграть свадьбу
# 13  130458.228857                 приобретение автомобиля
# 14  165127.911772              покупка жилой недвижимости
# 15  116820.904450  строительство собственной недвижимости
# 16  289202.704229                            недвижимость
# 17   90410.586745              строительство недвижимости
# 18   56823.777243      на покупку подержанного автомобиля
# 19  242831.107982            на покупку своего автомобиля
# 20  209552.644578                            недвижимость
# 21  131812.203909                 приобретение автомобиля
# 22  149681.140731      на покупку подержанного автомобиля
# 23  128265.720871                         сыграть свадьбу
# 24  290547.235997   операции с коммерческой недвижимостью
# 25   55112.757732                    покупка недвижимости
# 26            NaN                             образование
# 27  308848.983691  строительство собственной недвижимости
# 28  187863.237306  строительство собственной недвижимости
# 29            NaN        строительство жилой недвижимости
# 30  171456.067993   операции с коммерческой недвижимостью
# 31  275485.684538                                   жилье
# 32  139057.464207                   на проведение свадьбы
# 33  157245.786233                           покупка жилья
# 34  104660.449203         операции со своей недвижимостью
# 35   77805.677436                   на проведение свадьбы
# 36  138830.650734                              автомобили
# 37  154128.878672                 приобретение автомобиля
# 38  192247.298639                             образование
# 39  754240.797248                   заняться образованием
# 40  142865.579146                    покупка недвижимости
# 41            NaN        сделка с подержанным автомобилем
# 42   82065.089021                   получение образования
# 43  272957.133509                 приобретение автомобиля
# 44  100780.496749            на покупку своего автомобиля
# 45  106385.919724                   заняться образованием
# 46  182682.459898        сделка с подержанным автомобилем
# 47  356277.909345                   на проведение свадьбы
# 48  162065.516450  строительство собственной недвижимости
# 49   44591.806888                              автомобиль

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
data.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt  total_income
# count      21525.000000  21525.000000  1.935100e+04
# mean           0.972544      0.080883  1.674223e+05
# std            1.420324      0.272661  1.029716e+05
# min            0.000000      0.000000  2.066726e+04
# 25%            0.000000      0.000000  1.030532e+05
# 50%            0.000000      0.000000  1.450179e+05
# 75%            1.000000      0.000000  2.034351e+05
# max            4.000000      1.000000  2.265604e+06

# %% [markdown]
# **Вывод**

# %% [markdown]
# В столбце days_employed встречаются отрицательные значени. Также в этом столбце есть пропущенные значения NaN. Еще NaN встречается в столбце total_income. Их нужно заполнить и понять причину возникновения. total_income округлим и переведем в int, для удобства. Приведем education к общему регистру. Максимальное и минимальной количество детей, возможно опечатки. В столбце days_employed стаж у пенсионеров > 1000 лет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Подумай также о возможных причинах появления пропусков, а также о том, являются ли они случайными или нет. Можно высказать предварительные варианты их обработки.
#
# Первый взгляд на таблицу выполнен.
#
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %%
data[data['days_employed'].isna()].count() # узнаем количество пропущенных значений
# Out:
# children            2174
# days_employed          0
# dob_years           2174
# education           2174
# education_id        2174
# family_status       2174
# family_status_id    2174
# gender              2174
# income_type         2174
# debt                2174
# total_income           0
# purpose             2174
# dtype: int64

# %%
total_income_group_mean = data.groupby('income_type')['total_income'].transform('mean') # средний доход по типу занятости  
data['total_income'].fillna(total_income_group_mean, inplace=True) # заменяем NaN в 'total_income' на средний доход по типу занятости 

data['days_employed'] = data['days_employed'].apply(abs) # избавляемся от отрицательных значений в 'days_employed'

days_employed_group_mean = data.groupby('income_type')['days_employed'].transform('mean') # среднее 'days_employed' по типу занятости  
data['days_employed'].fillna(days_employed_group_mean, inplace=True)
data.tail(50)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 21475         0  365213.306266         52              среднее             1
# 21476         0    2539.502794         52               высшее             0
# 21477         0    1628.432350         54              среднее             1
# 21478         1     921.332705         28               Высшее             0
# 21479         0     685.565994         26              среднее             1
# 21480         0    8799.354717         45               высшее             0
# 21481         0     829.519627         30  неоконченное высшее             2
# 21482         1     865.081118         25              среднее             1
# 21483         2    2917.035232         38            начальное             3
# 21484         3     968.718123         35              среднее             1
# 21485         0  363996.449108         59               высшее             0
# 21486         0    1614.022809         36              СРЕДНЕЕ             1
# 21487         0    2376.789344         30              СРЕДНЕЕ             1
# 21488         0     354.755760         35               высшее             0
# 21489         2    2111.524398         47              Среднее             1
# 21490         2    1867.006757         32              среднее             1
# 21491        20     173.954460         27              среднее             1
# 21492         0    1618.645283         54              среднее             1
# 21493         1    1214.858885         38              среднее             1
# 21494         0     960.095747         39              среднее             1
# 21495         1    2326.499216         50              среднее             1
# 21496         1     759.680851         31              среднее             1
# 21497         0    2111.524398         48               ВЫСШЕЕ             0
# 21498         1    1330.627998         32              среднее             1
# 21499         0    9929.015065         57              среднее             1
# 21500         0     578.082757         26  неоконченное высшее             2
# 21501         0  334343.096304         57              среднее             1
# 21502         1    2326.499216         42              среднее             1
# 21503         0    3096.881131         58              среднее             1
# 21504         0  355235.728158         68              среднее             1
# 21505         0  338904.866406         53              среднее             1
# 21506         1    1556.249906         33               ВЫСШЕЕ             0
# 21507         1      79.832064         32              среднее             1
# 21508         0  386497.714078         62              среднее             1
# 21509         0  362161.054124         59               высшее             0
# 21510         2    2326.499216         28              среднее             1
# 21511         0     612.569129         29               высшее             0
# 21512         0     165.377752         26               высшее             0
# 21513         0    1166.216789         35              среднее             1
# 21514         0     280.469996         27  неоконченное высшее             2
# 21515         1     467.685130         28              среднее             1
# 21516         0     914.391429         42               высшее             0
# 21517         0     404.679034         42               высшее             0
# 21518         0  373995.710838         59              СРЕДНЕЕ             1
# 21519         1    2351.431934         37       ученая степень             4
# 21520         1    4529.316663         43              среднее             1
# 21521         0  343937.404131         67              среднее             1
# 21522         1    2113.346888         38              среднее             1
# 21523         3    3112.481705         38              среднее             1
# 21524         2    1984.507589         40              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 21475        женат / замужем                 0      F    пенсионер     1
# 21476        женат / замужем                 0      M    компаньон     0
# 21477       гражданский брак                 1      F    сотрудник     0
# 21478        женат / замужем                 0      F    сотрудник     0
# 21479        женат / замужем                 0      M    сотрудник     0
# 21480  Не женат / не замужем                 4      F    сотрудник     0
# 21481       гражданский брак                 1      M    сотрудник     0
# 21482        женат / замужем                 0      F    компаньон     0
# 21483       гражданский брак                 1      F    сотрудник     1
# 21484        женат / замужем                 0      M    сотрудник     0
# 21485        женат / замужем                 0      F    пенсионер     0
# 21486        женат / замужем                 0      F    сотрудник     1
# 21487       гражданский брак                 1      F    сотрудник     0
# 21488  Не женат / не замужем                 4      F    компаньон     0
# 21489        женат / замужем                 0      M    компаньон     0
# 21490        женат / замужем                 0      F    сотрудник     0
# 21491        женат / замужем                 0      F    сотрудник     0
# 21492        женат / замужем                 0      M    компаньон     0
# 21493        женат / замужем                 0      F    сотрудник     0
# 21494       гражданский брак                 1      M    компаньон     1
# 21495       гражданский брак                 1      F    сотрудник     0
# 21496        женат / замужем                 0      F    сотрудник     0
# 21497        женат / замужем                 0      F    компаньон     0
# 21498       гражданский брак                 1      M    сотрудник     0
# 21499       гражданский брак                 1      M    компаньон     0
# 21500  Не женат / не замужем                 4      M    компаньон     0
# 21501        женат / замужем                 0      F    пенсионер     0
# 21502        женат / замужем                 0      F    сотрудник     0
# 21503        женат / замужем                 0      F    сотрудник     0
# 21504        женат / замужем                 0      F    пенсионер     0
# 21505       гражданский брак                 1      M    пенсионер     0
# 21506       гражданский брак                 1      F    сотрудник     0
# 21507       гражданский брак                 1      F  госслужащий     0
# 21508        женат / замужем                 0      M    пенсионер     0
# 21509        женат / замужем                 0      M    пенсионер     0
# 21510        женат / замужем                 0      F    сотрудник     0
# 21511       гражданский брак                 1      F    сотрудник     1
# 21512  Не женат / не замужем                 4      M    компаньон     0
# 21513        женат / замужем                 0      F    сотрудник     0
# 21514  Не женат / не замужем                 4      M    компаньон     0
# 21515        женат / замужем                 0      F    сотрудник     1
# 21516        женат / замужем                 0      F    компаньон     0
# 21517       гражданский брак                 1      F    компаньон     0
# 21518        женат / замужем                 0      F    пенсионер     0
# 21519              в разводе                 3      M    сотрудник     0
# 21520       гражданский брак                 1      F    компаньон     0
# 21521        женат / замужем                 0      F    пенсионер     0
# 21522       гражданский брак                 1      M    сотрудник     1
# 21523        женат / замужем                 0      M    сотрудник     1
# 21524        женат / замужем                 0      F    сотрудник     0
#
#         total_income                                purpose
# 21475   48239.310903                        свой автомобиль
# 21476  527452.833253        операции со своей недвижимостью
# 21477   71733.906470                  на проведение свадьбы
# 21478  181185.864790                        свой автомобиль
# 21479  171504.352534                покупка жилья для сдачи
# 21480  146945.045428                           ремонт жилью
# 21481  440470.880955                  на покупку автомобиля
# 21482   94065.031245                        свой автомобиль
# 21483   77417.560520               операции с недвижимостью
# 21484   95667.452395                                  жилье
# 21485  267000.734155     на покупку подержанного автомобиля
# 21486   80763.856017                             автомобиль
# 21487   87834.565090                           недвижимость
# 21488  128897.486083                           недвижимость
# 21489  202417.461462                   сделка с автомобилем
# 21490   34767.965495  операции с коммерческой недвижимостью
# 21491  155520.899688     на покупку подержанного автомобиля
# 21492  295234.214807             покупка жилой недвижимости
# 21493  147502.599329                покупка жилья для семьи
# 21494  176369.594491             дополнительное образование
# 21495  161380.260488                                свадьба
# 21496  119392.620079                  на покупку автомобиля
# 21497  202417.461462             строительство недвижимости
# 21498  240767.575887                        сыграть свадьбу
# 21499  157553.158589                                свадьба
# 21500   77813.293365  операции с коммерческой недвижимостью
# 21501   86232.126549                                  жилье
# 21502  161380.260488       строительство жилой недвижимости
# 21503  264250.997662                  заняться образованием
# 21504   80566.321329             дополнительное образование
# 21505   75439.993167                        сыграть свадьбу
# 21506  145541.993320                                свадьба
# 21507   98180.279152       сделка с подержанным автомобилем
# 21508   72638.590915                           недвижимость
# 21509   73029.059379               операции с недвижимостью
# 21510  161380.260488                приобретение автомобиля
# 21511  140068.472941                покупка жилья для сдачи
# 21512  147301.457769  получение дополнительного образования
# 21513  250986.142309                          покупка жилья
# 21514  355988.407188             строительство недвижимости
# 21515  109486.327999                  заняться образованием
# 21516  322807.776603                   покупка своего жилья
# 21517  178059.553491           на покупку своего автомобиля
# 21518  153864.650328                   сделка с автомобилем
# 21519  115949.039788      покупка коммерческой недвижимости
# 21520  224791.862382                      операции с жильем
# 21521  155999.806512                   сделка с автомобилем
# 21522   89672.561153                           недвижимость
# 21523  244093.050500           на покупку своего автомобиля
# 21524   82047.418899                  на покупку автомобиля

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Соглашусь, тип занятости влияет на получаемый доход. Здорово, что ты заметил это и обработал пропуски таким способом.
#
# </div>

# %%
#dob_years_group_mean = data.groupby('income_type')['dob_years'].mean() # средний возраст по категории занятости
#data['dob_years'] = data['dob_years'].replace(0, dob_years_group_mean) # меняем 0 'dob_years' на средний возраст по категории занятости
#data[data['dob_years'] == 0].count()[0]

#data['dob_years'] = data.groupby('income_type')['dob_years'].mean().replace(0, dob_years_group_mean) # меняем 0 'dob_years' на средний возраст по категории занятости

dob_years_mean = data['dob_years'].mean() # средний возраст
data['dob_years'] = data['dob_years'].replace(0, int(dob_years_mean)) # заменим 0 на средний возраст

#data[data['dob_years'] == 0].count()[0] # проверяем количество 0

data['children'] = data['children'].apply(abs) # переведем отрицательное значение 'children' в положительное
data['children'] = data['children'].replace(20, 2) # заменим количество детей с 20 на 2

data.info()
data.tail(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB
#        children  days_employed  dob_years            education  education_id  \
# 21475         0  365213.306266         52              среднее             1
# 21476         0    2539.502794         52               высшее             0
# 21477         0    1628.432350         54              среднее             1
# 21478         1     921.332705         28               Высшее             0
# 21479         0     685.565994         26              среднее             1
# 21480         0    8799.354717         45               высшее             0
# 21481         0     829.519627         30  неоконченное высшее             2
# 21482         1     865.081118         25              среднее             1
# 21483         2    2917.035232         38            начальное             3
# 21484         3     968.718123         35              среднее             1
# 21485         0  363996.449108         59               высшее             0
# 21486         0    1614.022809         36              СРЕДНЕЕ             1
# 21487         0    2376.789344         30              СРЕДНЕЕ             1
# 21488         0     354.755760         35               высшее             0
# 21489         2    2111.524398         47              Среднее             1
# 21490         2    1867.006757         32              среднее             1
# 21491         2     173.954460         27              среднее             1
# 21492         0    1618.645283         54              среднее             1
# 21493         1    1214.858885         38              среднее             1
# 21494         0     960.095747         39              среднее             1
# 21495         1    2326.499216         50              среднее             1
# 21496         1     759.680851         31              среднее             1
# 21497         0    2111.524398         48               ВЫСШЕЕ             0
# 21498         1    1330.627998         32              среднее             1
# 21499         0    9929.015065         57              среднее             1
# 21500         0     578.082757         26  неоконченное высшее             2
# 21501         0  334343.096304         57              среднее             1
# 21502         1    2326.499216         42              среднее             1
# 21503         0    3096.881131         58              среднее             1
# 21504         0  355235.728158         68              среднее             1
# 21505         0  338904.866406         53              среднее             1
# 21506         1    1556.249906         33               ВЫСШЕЕ             0
# 21507         1      79.832064         32              среднее             1
# 21508         0  386497.714078         62              среднее             1
# 21509         0  362161.054124         59               высшее             0
# 21510         2    2326.499216         28              среднее             1
# 21511         0     612.569129         29               высшее             0
# 21512         0     165.377752         26               высшее             0
# 21513         0    1166.216789         35              среднее             1
# 21514         0     280.469996         27  неоконченное высшее             2
# 21515         1     467.685130         28              среднее             1
# 21516         0     914.391429         42               высшее             0
# 21517         0     404.679034         42               высшее             0
# 21518         0  373995.710838         59              СРЕДНЕЕ             1
# 21519         1    2351.431934         37       ученая степень             4
# 21520         1    4529.316663         43              среднее             1
# 21521         0  343937.404131         67              среднее             1
# 21522         1    2113.346888         38              среднее             1
# 21523         3    3112.481705         38              среднее             1
# 21524         2    1984.507589         40              среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 21475        женат / замужем                 0      F    пенсионер     1
# 21476        женат / замужем                 0      M    компаньон     0
# 21477       гражданский брак                 1      F    сотрудник     0
# 21478        женат / замужем                 0      F    сотрудник     0
# 21479        женат / замужем                 0      M    сотрудник     0
# 21480  Не женат / не замужем                 4      F    сотрудник     0
# 21481       гражданский брак                 1      M    сотрудник     0
# 21482        женат / замужем                 0      F    компаньон     0
# 21483       гражданский брак                 1      F    сотрудник     1
# 21484        женат / замужем                 0      M    сотрудник     0
# 21485        женат / замужем                 0      F    пенсионер     0
# 21486        женат / замужем                 0      F    сотрудник     1
# 21487       гражданский брак                 1      F    сотрудник     0
# 21488  Не женат / не замужем                 4      F    компаньон     0
# 21489        женат / замужем                 0      M    компаньон     0
# 21490        женат / замужем                 0      F    сотрудник     0
# 21491        женат / замужем                 0      F    сотрудник     0
# 21492        женат / замужем                 0      M    компаньон     0
# 21493        женат / замужем                 0      F    сотрудник     0
# 21494       гражданский брак                 1      M    компаньон     1
# 21495       гражданский брак                 1      F    сотрудник     0
# 21496        женат / замужем                 0      F    сотрудник     0
# 21497        женат / замужем                 0      F    компаньон     0
# 21498       гражданский брак                 1      M    сотрудник     0
# 21499       гражданский брак                 1      M    компаньон     0
# 21500  Не женат / не замужем                 4      M    компаньон     0
# 21501        женат / замужем                 0      F    пенсионер     0
# 21502        женат / замужем                 0      F    сотрудник     0
# 21503        женат / замужем                 0      F    сотрудник     0
# 21504        женат / замужем                 0      F    пенсионер     0
# 21505       гражданский брак                 1      M    пенсионер     0
# 21506       гражданский брак                 1      F    сотрудник     0
# 21507       гражданский брак                 1      F  госслужащий     0
# 21508        женат / замужем                 0      M    пенсионер     0
# 21509        женат / замужем                 0      M    пенсионер     0
# 21510        женат / замужем                 0      F    сотрудник     0
# 21511       гражданский брак                 1      F    сотрудник     1
# 21512  Не женат / не замужем                 4      M    компаньон     0
# 21513        женат / замужем                 0      F    сотрудник     0
# 21514  Не женат / не замужем                 4      M    компаньон     0
# 21515        женат / замужем                 0      F    сотрудник     1
# 21516        женат / замужем                 0      F    компаньон     0
# 21517       гражданский брак                 1      F    компаньон     0
# 21518        женат / замужем                 0      F    пенсионер     0
# 21519              в разводе                 3      M    сотрудник     0
# 21520       гражданский брак                 1      F    компаньон     0
# 21521        женат / замужем                 0      F    пенсионер     0
# 21522       гражданский брак                 1      M    сотрудник     1
# 21523        женат / замужем                 0      M    сотрудник     1
# 21524        женат / замужем                 0      F    сотрудник     0
#
#         total_income                                purpose
# 21475   48239.310903                        свой автомобиль
# 21476  527452.833253        операции со своей недвижимостью
# 21477   71733.906470                  на проведение свадьбы
# 21478  181185.864790                        свой автомобиль
# 21479  171504.352534                покупка жилья для сдачи
# 21480  146945.045428                           ремонт жилью
# 21481  440470.880955                  на покупку автомобиля
# 21482   94065.031245                        свой автомобиль
# 21483   77417.560520               операции с недвижимостью
# 21484   95667.452395                                  жилье
# 21485  267000.734155     на покупку подержанного автомобиля
# 21486   80763.856017                             автомобиль
# 21487   87834.565090                           недвижимость
# 21488  128897.486083                           недвижимость
# 21489  202417.461462                   сделка с автомобилем
# 21490   34767.965495  операции с коммерческой недвижимостью
# 21491  155520.899688     на покупку подержанного автомобиля
# 21492  295234.214807             покупка жилой недвижимости
# 21493  147502.599329                покупка жилья для семьи
# 21494  176369.594491             дополнительное образование
# 21495  161380.260488                                свадьба
# 21496  119392.620079                  на покупку автомобиля
# 21497  202417.461462             строительство недвижимости
# 21498  240767.575887                        сыграть свадьбу
# 21499  157553.158589                                свадьба
# 21500   77813.293365  операции с коммерческой недвижимостью
# 21501   86232.126549                                  жилье
# 21502  161380.260488       строительство жилой недвижимости
# 21503  264250.997662                  заняться образованием
# 21504   80566.321329             дополнительное образование
# 21505   75439.993167                        сыграть свадьбу
# 21506  145541.993320                                свадьба
# 21507   98180.279152       сделка с подержанным автомобилем
# 21508   72638.590915                           недвижимость
# 21509   73029.059379               операции с недвижимостью
# 21510  161380.260488                приобретение автомобиля
# 21511  140068.472941                покупка жилья для сдачи
# 21512  147301.457769  получение дополнительного образования
# 21513  250986.142309                          покупка жилья
# 21514  355988.407188             строительство недвижимости
# 21515  109486.327999                  заняться образованием
# 21516  322807.776603                   покупка своего жилья
# 21517  178059.553491           на покупку своего автомобиля
# 21518  153864.650328                   сделка с автомобилем
# 21519  115949.039788      покупка коммерческой недвижимости
# 21520  224791.862382                      операции с жильем
# 21521  155999.806512                   сделка с автомобилем
# 21522   89672.561153                           недвижимость
# 21523  244093.050500           на покупку своего автомобиля
# 21524   82047.418899                  на покупку автомобиля

# %% [markdown]
# **Вывод**

# %% [markdown]
# Заменили пропущенные значения по доходу на среднее для каждой категории занятости (Я думаю так будет точнее). Избавились от отрицательных значений в трудовом стаже, заполнили пропуски средним значение по категории занятости. Возможно клиенты не указывали свой возравст и доход. У пенсионеров получился средний стаж 365000 дней. Этот столбец для решения задачи нам не пригодится, но об ошибке необходимо предупредить. Знасения 0 в столбце возраст заменил на среднее по столбцу (хотел заменить на среднее по категории занятости, но, почемуто не получилось. Код закоментировал, может подскажете, где ошибка). Исправили количество детей с 20 на 2 (скорее всего опечатка).

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Классно, что ты также заметил и ошибки в данных. Их исправление поможет нам увеличить точность последующего анализа.
#
# </div>

# %% [markdown]
# ### Замена типа данных

# %%
data['total_income'] = data['total_income'].astype('int') # преводим значения 'total_income' в челое int для удобства
data['dob_years'] = data['dob_years'].astype('int') # преводим значения 'dob_years' в int для удобства
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose
# 0            253875                 покупка жилья
# 1            112080       приобретение автомобиля
# 2            145885                 покупка жилья
# 3            267628    дополнительное образование
# 4            158616               сыграть свадьбу
# ...             ...                           ...
# 21520        224791             операции с жильем
# 21521        155999          сделка с автомобилем
# 21522         89672                  недвижимость
# 21523        244093  на покупку своего автомобиля
# 21524         82047         на покупку автомобиля
#
# [21525 rows x 12 columns]

# %% [markdown]
# **Вывод**

# %% [markdown]
# Преводим значения 'dob_years' и 'total_income' в int для удобства

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Исходя из общей информации о таблице, мы видим, что два столбца имеют вещественный тип данных, который и надо заменить на целочисленный. Эта замена произведена верно. Также хорошо бы освоить метод to_numeric() для будущих работ.
#
# </div>

# %% [markdown]
# ### Обработка дубликатов

# %%
data['education'] = data['education'].str.lower() # привели 'education' к нижнему регистру
data.duplicated().sum() # посмотрим на суммарное количество дубликатов
# Out:
# 71

# %%
data[data.duplicated(keep=False)].sort_values(by=['total_income', 'dob_years']) # посмотрим на дубликаты
# Out:
#        children  days_employed  dob_years education  education_id  \
# 17787         0  365003.491245         54   среднее             1
# 21415         0  365003.491245         54   среднее             1
# 3344          0  365003.491245         56   среднее             1
# 9627          0  365003.491245         56   среднее             1
# 13300         0  365003.491245         56   среднее             1
# ...         ...            ...        ...       ...           ...
# 19369         0    2111.524398         45   среднее             1
# 9920          0    2111.524398         51   среднее             1
# 15991         0    2111.524398         51   среднее             1
# 2254          0    2111.524398         54    высшее             0
# 17379         0    2111.524398         54    высшее             0
#
#           family_status  family_status_id gender income_type  debt  \
# 17787   женат / замужем                 0      F   пенсионер     0
# 21415   женат / замужем                 0      F   пенсионер     0
# 3344    женат / замужем                 0      F   пенсионер     0
# 9627    женат / замужем                 0      F   пенсионер     0
# 13300   женат / замужем                 0      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 19369  гражданский брак                 1      F   компаньон     0
# 9920   гражданский брак                 1      F   компаньон     0
# 15991  гражданский брак                 1      F   компаньон     0
# 2254    женат / замужем                 0      M   компаньон     0
# 17379   женат / замужем                 0      M   компаньон     0
#
#        total_income                                purpose
# 17787        137127                      операции с жильем
# 21415        137127                      операции с жильем
# 3344         137127        операции со своей недвижимостью
# 9627         137127        операции со своей недвижимостью
# 13300        137127                  на покупку автомобиля
# ...             ...                                    ...
# 19369        202417                                свадьба
# 9920         202417                  на проведение свадьбы
# 15991        202417                  на проведение свадьбы
# 2254         202417  операции с коммерческой недвижимостью
# 17379        202417  операции с коммерческой недвижимостью
#
# [137 rows x 12 columns]

# %%
data = data.drop_duplicates().reset_index() # удаляем дубликаты

# %%
data.duplicated().sum() # проверяем еще раз дубликаты
# Out:
# 0

# %% [markdown]
# **Вывод**

# %% [markdown]
# Привели 'education' к нижнему регистру. Выявили и удалили дубликаты. Причина появления дублей, скорее всего, в работе скрипта. Человек несколько раз нажимал на отправку формы и форма отправлялась несколько раз.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Дубликаты вызывают смещение финальных результатов, поэтому их и надо удалять. Конечно, в данных нет уникального идентификатора, однако надо уметь удалять дубликаты. Метод drop_duplicates() использован верно.
#
# </div>

# %% [markdown]
# ### Лемматизация

# %%
data['purpose'].value_counts() # посмотрим на все цели кредита
# Out:
# свадьба                                   791
# на проведение свадьбы                     768
# сыграть свадьбу                           765
# операции с недвижимостью                  675
# покупка коммерческой недвижимости         661
# операции с жильем                         652
# покупка жилья для сдачи                   651
# операции с коммерческой недвижимостью     650
# покупка жилья                             646
# жилье                                     646
# покупка жилья для семьи                   638
# строительство собственной недвижимости    635
# недвижимость                              633
# операции со своей недвижимостью           627
# строительство жилой недвижимости          624
# покупка недвижимости                      621
# покупка своего жилья                      620
# строительство недвижимости                619
# ремонт жилью                              607
# покупка жилой недвижимости                606
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                494
# сделка с подержанным автомобилем          486
# на покупку подержанного автомобиля        478
# свой автомобиль                           478
# автомобили                                478
# на покупку автомобиля                     471
# приобретение автомобиля                   461
# дополнительное образование                460
# сделка с автомобилем                      455
# высшее образование                        452
# образование                               447
# получение дополнительного образования     446
# получение образования                     442
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     408
# Name: purpose, dtype: int64

# %%
from pymystem3 import Mystem
m = Mystem()
def purpose_lemmas(purpose):
     lemmas = m.lemmatize(purpose)  # лемматизировали цели кредита
     return lemmas                
data['purpose_lemmas'] = data['purpose'].apply(purpose_lemmas)
data.head(50)
# Out:
#     index  children  days_employed  dob_years            education  \
# 0       0         1    8437.673028         42               высшее
# 1       1         1    4024.803754         36              среднее
# 2       2         0    5623.422610         33              среднее
# 3       3         3    4124.747207         32              среднее
# 4       4         0  340266.072047         53              среднее
# 5       5         0     926.185831         27               высшее
# 6       6         0    2879.202052         43               высшее
# 7       7         0     152.779569         50              среднее
# 8       8         2    6929.865299         35               высшее
# 9       9         0    2188.756445         41              среднее
# 10     10         2    4171.483647         36               высшее
# 11     11         0     792.701887         40              среднее
# 12     12         0  365003.491245         65              среднее
# 13     13         0    1846.641941         54  неоконченное высшее
# 14     14         0    1844.956182         56               высшее
# 15     15         1     972.364419         26              среднее
# 16     16         0    1719.934226         35              среднее
# 17     17         0    2369.999720         33               высшее
# 18     18         0  400281.136913         53              среднее
# 19     19         0   10038.818549         48              среднее
# 20     20         1    1311.604166         36              среднее
# 21     21         1     253.685166         33              среднее
# 22     22         1    1766.644138         24              среднее
# 23     23         0     272.981385         21               высшее
# 24     24         1  338551.952911         57              среднее
# 25     25         0  363548.489348         67              среднее
# 26     26         0    3399.896902         41              среднее
# 27     27         0     529.191635         28               высшее
# 28     28         1     717.274324         26               высшее
# 29     29         0  365003.491245         63              среднее
# 30     30         1  335581.668515         62              среднее
# 31     31         0    1682.083438         47            начальное
# 32     32         0    4649.910832         34              среднее
# 33     33         0    1548.637544         48              среднее
# 34     34         0    4488.067031         35              среднее
# 35     35         0  394021.072184         68              среднее
# 36     36         0     176.216688         33              среднее
# 37     37         0    6448.810860         43               высшее
# 38     38         0     597.881827         25               высшее
# 39     39         0     650.587796         31               высшее
# 40     40         0    1030.362606         30              среднее
# 41     41         0    3399.896902         50              среднее
# 42     42         0    1257.496190         20  неоконченное высшее
# 43     43         0    4375.681384         43  неоконченное высшее
# 44     44         1    1362.041728         26              среднее
# 45     45         1    1039.451741         49              среднее
# 46     46         2    2262.712304         37              среднее
# 47     47         1    2689.137274         33               высшее
# 48     48         0    3341.067886         45              среднее
# 49     49         0    1181.443228         54              среднее
#
#     education_id          family_status  family_status_id gender  income_type  \
# 0              0        женат / замужем                 0      F    сотрудник
# 1              1        женат / замужем                 0      F    сотрудник
# 2              1        женат / замужем                 0      M    сотрудник
# 3              1        женат / замужем                 0      M    сотрудник
# 4              1       гражданский брак                 1      F    пенсионер
# 5              0       гражданский брак                 1      M    компаньон
# 6              0        женат / замужем                 0      F    компаньон
# 7              1        женат / замужем                 0      M    сотрудник
# 8              0       гражданский брак                 1      F    сотрудник
# 9              1        женат / замужем                 0      M    сотрудник
# 10             0        женат / замужем                 0      M    компаньон
# 11             1        женат / замужем                 0      F    сотрудник
# 12             1       гражданский брак                 1      M    пенсионер
# 13             2        женат / замужем                 0      F    сотрудник
# 14             0       гражданский брак                 1      F    компаньон
# 15             1        женат / замужем                 0      F    сотрудник
# 16             1        женат / замужем                 0      F    сотрудник
# 17             0       гражданский брак                 1      M    сотрудник
# 18             1         вдовец / вдова                 2      F    пенсионер
# 19             1              в разводе                 3      F    сотрудник
# 20             1        женат / замужем                 0      M    сотрудник
# 21             1       гражданский брак                 1      F    сотрудник
# 22             1       гражданский брак                 1      F    сотрудник
# 23             0       гражданский брак                 1      M    сотрудник
# 24             1  Не женат / не замужем                 4      F    пенсионер
# 25             1        женат / замужем                 0      M    пенсионер
# 26             1        женат / замужем                 0      M  госслужащий
# 27             0        женат / замужем                 0      M    сотрудник
# 28             0        женат / замужем                 0      F    сотрудник
# 29             1  Не женат / не замужем                 4      F    пенсионер
# 30             1        женат / замужем                 0      F    пенсионер
# 31             3        женат / замужем                 0      F    сотрудник
# 32             1       гражданский брак                 1      F    сотрудник
# 33             1        женат / замужем                 0      F    компаньон
# 34             1        женат / замужем                 0      F    сотрудник
# 35             1       гражданский брак                 1      M    пенсионер
# 36             1  Не женат / не замужем                 4      M    сотрудник
# 37             0       гражданский брак                 1      F    компаньон
# 38             0  Не женат / не замужем                 4      M    сотрудник
# 39             0       гражданский брак                 1      F    компаньон
# 40             1  Не женат / не замужем                 4      M    компаньон
# 41             1        женат / замужем                 0      F  госслужащий
# 42             2  Не женат / не замужем                 4      F    сотрудник
# 43             2              в разводе                 3      F    компаньон
# 44             1        женат / замужем                 0      F    сотрудник
# 45             1  Не женат / не замужем                 4      F    сотрудник
# 46             1        женат / замужем                 0      F    компаньон
# 47             0       гражданский брак                 1      M  госслужащий
# 48             1        женат / замужем                 0      F    сотрудник
# 49             1        женат / замужем                 0      F    сотрудник
#
#     debt  total_income                                 purpose  \
# 0      0        253875                           покупка жилья
# 1      0        112080                 приобретение автомобиля
# 2      0        145885                           покупка жилья
# 3      0        267628              дополнительное образование
# 4      0        158616                         сыграть свадьбу
# 5      0        255763                           покупка жилья
# 6      0        240525                       операции с жильем
# 7      0        135823                             образование
# 8      0         95856                   на проведение свадьбы
# 9      0        144425                 покупка жилья для семьи
# 10     0        113943                    покупка недвижимости
# 11     0         77069       покупка коммерческой недвижимости
# 12     0        137127                         сыграть свадьбу
# 13     0        130458                 приобретение автомобиля
# 14     1        165127              покупка жилой недвижимости
# 15     0        116820  строительство собственной недвижимости
# 16     0        289202                            недвижимость
# 17     0         90410              строительство недвижимости
# 18     0         56823      на покупку подержанного автомобиля
# 19     0        242831            на покупку своего автомобиля
# 20     0        209552                            недвижимость
# 21     0        131812                 приобретение автомобиля
# 22     0        149681      на покупку подержанного автомобиля
# 23     0        128265                         сыграть свадьбу
# 24     0        290547   операции с коммерческой недвижимостью
# 25     0         55112                    покупка недвижимости
# 26     0        170898                             образование
# 27     0        308848  строительство собственной недвижимости
# 28     0        187863  строительство собственной недвижимости
# 29     0        137127        строительство жилой недвижимости
# 30     0        171456   операции с коммерческой недвижимостью
# 31     0        275485                                   жилье
# 32     1        139057                   на проведение свадьбы
# 33     0        157245                           покупка жилья
# 34     0        104660         операции со своей недвижимостью
# 35     0         77805                   на проведение свадьбы
# 36     0        138830                              автомобили
# 37     0        154128                 приобретение автомобиля
# 38     1        192247                             образование
# 39     0        754240                   заняться образованием
# 40     0        142865                    покупка недвижимости
# 41     0        170898        сделка с подержанным автомобилем
# 42     0         82065                   получение образования
# 43     0        272957                 приобретение автомобиля
# 44     0        100780            на покупку своего автомобиля
# 45     0        106385                   заняться образованием
# 46     0        182682        сделка с подержанным автомобилем
# 47     0        356277                   на проведение свадьбы
# 48     0        162065  строительство собственной недвижимости
# 49     0         44591                              автомобиль
#
#                                        purpose_lemmas
# 0                             [покупка,  , жилье, \n]
# 1                   [приобретение,  , автомобиль, \n]
# 2                             [покупка,  , жилье, \n]
# 3                [дополнительный,  , образование, \n]
# 4                           [сыграть,  , свадьба, \n]
# 5                             [покупка,  , жилье, \n]
# 6                      [операция,  , с,  , жилье, \n]
# 7                                   [образование, \n]
# 8                 [на,  , проведение,  , свадьба, \n]
# 9           [покупка,  , жилье,  , для,  , семья, \n]
# 10                     [покупка,  , недвижимость, \n]
# 11    [покупка,  , коммерческий,  , недвижимость, \n]
# 12                          [сыграть,  , свадьба, \n]
# 13                  [приобретение,  , автомобиль, \n]
# 14           [покупка,  , жилой,  , недвижимость, \n]
# 15  [строительство,  , собственный,  , недвижимост...
# 16                                 [недвижимость, \n]
# 17               [строительство,  , недвижимость, \n]
# 18  [на,  , покупка,  , подержать,  , автомобиль, \n]
# 19       [на,  , покупка,  , свой,  , автомобиль, \n]
# 20                                 [недвижимость, \n]
# 21                  [приобретение,  , автомобиль, \n]
# 22  [на,  , покупка,  , подержать,  , автомобиль, \n]
# 23                          [сыграть,  , свадьба, \n]
# 24  [операция,  , с,  , коммерческий,  , недвижимо...
# 25                     [покупка,  , недвижимость, \n]
# 26                                  [образование, \n]
# 27  [строительство,  , собственный,  , недвижимост...
# 28  [строительство,  , собственный,  , недвижимост...
# 29     [строительство,  , жилой,  , недвижимость, \n]
# 30  [операция,  , с,  , коммерческий,  , недвижимо...
# 31                                        [жилье, \n]
# 32                [на,  , проведение,  , свадьба, \n]
# 33                            [покупка,  , жилье, \n]
# 34    [операция,  , со,  , свой,  , недвижимость, \n]
# 35                [на,  , проведение,  , свадьба, \n]
# 36                                   [автомобиль, \n]
# 37                  [приобретение,  , автомобиль, \n]
# 38                                  [образование, \n]
# 39                   [заниматься,  , образование, \n]
# 40                     [покупка,  , недвижимость, \n]
# 41  [сделка,  , с,  , подержанный,  , автомобиль, \n]
# 42                    [получение,  , образование, \n]
# 43                  [приобретение,  , автомобиль, \n]
# 44       [на,  , покупка,  , свой,  , автомобиль, \n]
# 45                   [заниматься,  , образование, \n]
# 46  [сделка,  , с,  , подержанный,  , автомобиль, \n]
# 47                [на,  , проведение,  , свадьба, \n]
# 48  [строительство,  , собственный,  , недвижимост...
# 49                                   [автомобиль, \n]

# %%
data['purpose_lemmas'].value_counts() # выделим топ целей (автомобиль, свадьба, недвижимость, образование)
# Out:
# [автомобиль, \n]                                          972
# [свадьба, \n]                                             791
# [на,  , проведение,  , свадьба, \n]                       768
# [сыграть,  , свадьба, \n]                                 765
# [операция,  , с,  , недвижимость, \n]                     675
# [покупка,  , коммерческий,  , недвижимость, \n]           661
# [операция,  , с,  , жилье, \n]                            652
# [покупка,  , жилье,  , для,  , сдача, \n]                 651
# [операция,  , с,  , коммерческий,  , недвижимость, \n]    650
# [покупка,  , жилье, \n]                                   646
# [жилье, \n]                                               646
# [покупка,  , жилье,  , для,  , семья, \n]                 638
# [строительство,  , собственный,  , недвижимость, \n]      635
# [недвижимость, \n]                                        633
# [операция,  , со,  , свой,  , недвижимость, \n]           627
# [строительство,  , жилой,  , недвижимость, \n]            624
# [покупка,  , недвижимость, \n]                            621
# [покупка,  , свой,  , жилье, \n]                          620
# [строительство,  , недвижимость, \n]                      619
# [ремонт,  , жилье, \n]                                    607
# [покупка,  , жилой,  , недвижимость, \n]                  606
# [на,  , покупка,  , свой,  , автомобиль, \n]              505
# [заниматься,  , высокий,  , образование, \n]              496
# [сделка,  , с,  , подержанный,  , автомобиль, \n]         486
# [свой,  , автомобиль, \n]                                 478
# [на,  , покупка,  , подержать,  , автомобиль, \n]         478
# [на,  , покупка,  , автомобиль, \n]                       471
# [приобретение,  , автомобиль, \n]                         461
# [дополнительный,  , образование, \n]                      460
# [сделка,  , с,  , автомобиль, \n]                         455
# [высокий,  , образование, \n]                             452
# [образование, \n]                                         447
# [получение,  , дополнительный,  , образование, \n]        446
# [получение,  , образование, \n]                           442
# [профильный,  , образование, \n]                          436
# [получение,  , высокий,  , образование, \n]               426
# [заниматься,  , образование, \n]                          408
# Name: purpose_lemmas, dtype: int64

# %% [markdown]
# **Вывод**

# %% [markdown]
# Лемматизацию записал в новый столбец для дальнейшей категоризации. Перед лемматизацией вывел цели для ознакомления. После лемматизации веделил основные категории (автомобиль, свадьба, недвижимость, образование).

# %% [markdown]
# ### Категоризация данных

# %%
def purpose_cat(purpose):    # присвоили категории всем клиентам по целям
    if 'автомобиль'in purpose:
        return 'авто'
    elif 'свадьба' in purpose:
        return 'свадьба'
    elif 'недвижимость' in purpose or 'жилье' in purpose:
        return 'недвижимость'
    elif 'образование' in purpose:
        return 'образование'
    else:
        return 'другое'
data['purpose_cat'] = data['purpose_lemmas'].apply(purpose_cat)
data['purpose_cat'].value_counts()
# Out:
# недвижимость    10811
# авто             4306
# образование      4013
# свадьба          2324
# Name: purpose_cat, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Круто, ты сделал самую сложную часть проекта. Использовал нужные методы, и даже провел группировку с помощью собственной функции. Выбор основных целей кредитов обоснован ранее.
#
# </div>

# %%
data['dob_years'].sort_values() # смотрим возраст заемщиков
# Out:
# 5558     19
# 12998    19
# 9208     19
# 20166    19
# 2725     19
#          ..
# 4891     74
# 12297    74
# 3458     74
# 2557     74
# 8870     75
# Name: dob_years, Length: 21454, dtype: int64

# %%
def dob_years_group(age): # категории по возрасту
    if 18 <= age <= 35:
        return 'молодые'
    if 36 <= age <= 65:
        return 'средний возраст'
    if age > 65:
        return 'пенсионеры'
dob_years_group(66)
# Out:
# 'пенсионеры'

# %%
data['dob_years_group'] = data['dob_years'].apply(dob_years_group)
data.head(50)
# Out:
#     index  children  days_employed  dob_years            education  \
# 0       0         1    8437.673028         42               высшее
# 1       1         1    4024.803754         36              среднее
# 2       2         0    5623.422610         33              среднее
# 3       3         3    4124.747207         32              среднее
# 4       4         0  340266.072047         53              среднее
# 5       5         0     926.185831         27               высшее
# 6       6         0    2879.202052         43               высшее
# 7       7         0     152.779569         50              среднее
# 8       8         2    6929.865299         35               высшее
# 9       9         0    2188.756445         41              среднее
# 10     10         2    4171.483647         36               высшее
# 11     11         0     792.701887         40              среднее
# 12     12         0  365003.491245         65              среднее
# 13     13         0    1846.641941         54  неоконченное высшее
# 14     14         0    1844.956182         56               высшее
# 15     15         1     972.364419         26              среднее
# 16     16         0    1719.934226         35              среднее
# 17     17         0    2369.999720         33               высшее
# 18     18         0  400281.136913         53              среднее
# 19     19         0   10038.818549         48              среднее
# 20     20         1    1311.604166         36              среднее
# 21     21         1     253.685166         33              среднее
# 22     22         1    1766.644138         24              среднее
# 23     23         0     272.981385         21               высшее
# 24     24         1  338551.952911         57              среднее
# 25     25         0  363548.489348         67              среднее
# 26     26         0    3399.896902         41              среднее
# 27     27         0     529.191635         28               высшее
# 28     28         1     717.274324         26               высшее
# 29     29         0  365003.491245         63              среднее
# 30     30         1  335581.668515         62              среднее
# 31     31         0    1682.083438         47            начальное
# 32     32         0    4649.910832         34              среднее
# 33     33         0    1548.637544         48              среднее
# 34     34         0    4488.067031         35              среднее
# 35     35         0  394021.072184         68              среднее
# 36     36         0     176.216688         33              среднее
# 37     37         0    6448.810860         43               высшее
# 38     38         0     597.881827         25               высшее
# 39     39         0     650.587796         31               высшее
# 40     40         0    1030.362606         30              среднее
# 41     41         0    3399.896902         50              среднее
# 42     42         0    1257.496190         20  неоконченное высшее
# 43     43         0    4375.681384         43  неоконченное высшее
# 44     44         1    1362.041728         26              среднее
# 45     45         1    1039.451741         49              среднее
# 46     46         2    2262.712304         37              среднее
# 47     47         1    2689.137274         33               высшее
# 48     48         0    3341.067886         45              среднее
# 49     49         0    1181.443228         54              среднее
#
#     education_id          family_status  family_status_id gender  income_type  \
# 0              0        женат / замужем                 0      F    сотрудник
# 1              1        женат / замужем                 0      F    сотрудник
# 2              1        женат / замужем                 0      M    сотрудник
# 3              1        женат / замужем                 0      M    сотрудник
# 4              1       гражданский брак                 1      F    пенсионер
# 5              0       гражданский брак                 1      M    компаньон
# 6              0        женат / замужем                 0      F    компаньон
# 7              1        женат / замужем                 0      M    сотрудник
# 8              0       гражданский брак                 1      F    сотрудник
# 9              1        женат / замужем                 0      M    сотрудник
# 10             0        женат / замужем                 0      M    компаньон
# 11             1        женат / замужем                 0      F    сотрудник
# 12             1       гражданский брак                 1      M    пенсионер
# 13             2        женат / замужем                 0      F    сотрудник
# 14             0       гражданский брак                 1      F    компаньон
# 15             1        женат / замужем                 0      F    сотрудник
# 16             1        женат / замужем                 0      F    сотрудник
# 17             0       гражданский брак                 1      M    сотрудник
# 18             1         вдовец / вдова                 2      F    пенсионер
# 19             1              в разводе                 3      F    сотрудник
# 20             1        женат / замужем                 0      M    сотрудник
# 21             1       гражданский брак                 1      F    сотрудник
# 22             1       гражданский брак                 1      F    сотрудник
# 23             0       гражданский брак                 1      M    сотрудник
# 24             1  Не женат / не замужем                 4      F    пенсионер
# 25             1        женат / замужем                 0      M    пенсионер
# 26             1        женат / замужем                 0      M  госслужащий
# 27             0        женат / замужем                 0      M    сотрудник
# 28             0        женат / замужем                 0      F    сотрудник
# 29             1  Не женат / не замужем                 4      F    пенсионер
# 30             1        женат / замужем                 0      F    пенсионер
# 31             3        женат / замужем                 0      F    сотрудник
# 32             1       гражданский брак                 1      F    сотрудник
# 33             1        женат / замужем                 0      F    компаньон
# 34             1        женат / замужем                 0      F    сотрудник
# 35             1       гражданский брак                 1      M    пенсионер
# 36             1  Не женат / не замужем                 4      M    сотрудник
# 37             0       гражданский брак                 1      F    компаньон
# 38             0  Не женат / не замужем                 4      M    сотрудник
# 39             0       гражданский брак                 1      F    компаньон
# 40             1  Не женат / не замужем                 4      M    компаньон
# 41             1        женат / замужем                 0      F  госслужащий
# 42             2  Не женат / не замужем                 4      F    сотрудник
# 43             2              в разводе                 3      F    компаньон
# 44             1        женат / замужем                 0      F    сотрудник
# 45             1  Не женат / не замужем                 4      F    сотрудник
# 46             1        женат / замужем                 0      F    компаньон
# 47             0       гражданский брак                 1      M  госслужащий
# 48             1        женат / замужем                 0      F    сотрудник
# 49             1        женат / замужем                 0      F    сотрудник
#
#     debt  total_income                                 purpose  \
# 0      0        253875                           покупка жилья
# 1      0        112080                 приобретение автомобиля
# 2      0        145885                           покупка жилья
# 3      0        267628              дополнительное образование
# 4      0        158616                         сыграть свадьбу
# 5      0        255763                           покупка жилья
# 6      0        240525                       операции с жильем
# 7      0        135823                             образование
# 8      0         95856                   на проведение свадьбы
# 9      0        144425                 покупка жилья для семьи
# 10     0        113943                    покупка недвижимости
# 11     0         77069       покупка коммерческой недвижимости
# 12     0        137127                         сыграть свадьбу
# 13     0        130458                 приобретение автомобиля
# 14     1        165127              покупка жилой недвижимости
# 15     0        116820  строительство собственной недвижимости
# 16     0        289202                            недвижимость
# 17     0         90410              строительство недвижимости
# 18     0         56823      на покупку подержанного автомобиля
# 19     0        242831            на покупку своего автомобиля
# 20     0        209552                            недвижимость
# 21     0        131812                 приобретение автомобиля
# 22     0        149681      на покупку подержанного автомобиля
# 23     0        128265                         сыграть свадьбу
# 24     0        290547   операции с коммерческой недвижимостью
# 25     0         55112                    покупка недвижимости
# 26     0        170898                             образование
# 27     0        308848  строительство собственной недвижимости
# 28     0        187863  строительство собственной недвижимости
# 29     0        137127        строительство жилой недвижимости
# 30     0        171456   операции с коммерческой недвижимостью
# 31     0        275485                                   жилье
# 32     1        139057                   на проведение свадьбы
# 33     0        157245                           покупка жилья
# 34     0        104660         операции со своей недвижимостью
# 35     0         77805                   на проведение свадьбы
# 36     0        138830                              автомобили
# 37     0        154128                 приобретение автомобиля
# 38     1        192247                             образование
# 39     0        754240                   заняться образованием
# 40     0        142865                    покупка недвижимости
# 41     0        170898        сделка с подержанным автомобилем
# 42     0         82065                   получение образования
# 43     0        272957                 приобретение автомобиля
# 44     0        100780            на покупку своего автомобиля
# 45     0        106385                   заняться образованием
# 46     0        182682        сделка с подержанным автомобилем
# 47     0        356277                   на проведение свадьбы
# 48     0        162065  строительство собственной недвижимости
# 49     0         44591                              автомобиль
#
#                                        purpose_lemmas   purpose_cat  \
# 0                             [покупка,  , жилье, \n]  недвижимость
# 1                   [приобретение,  , автомобиль, \n]          авто
# 2                             [покупка,  , жилье, \n]  недвижимость
# 3                [дополнительный,  , образование, \n]   образование
# 4                           [сыграть,  , свадьба, \n]       свадьба
# 5                             [покупка,  , жилье, \n]  недвижимость
# 6                      [операция,  , с,  , жилье, \n]  недвижимость
# 7                                   [образование, \n]   образование
# 8                 [на,  , проведение,  , свадьба, \n]       свадьба
# 9           [покупка,  , жилье,  , для,  , семья, \n]  недвижимость
# 10                     [покупка,  , недвижимость, \n]  недвижимость
# 11    [покупка,  , коммерческий,  , недвижимость, \n]  недвижимость
# 12                          [сыграть,  , свадьба, \n]       свадьба
# 13                  [приобретение,  , автомобиль, \n]          авто
# 14           [покупка,  , жилой,  , недвижимость, \n]  недвижимость
# 15  [строительство,  , собственный,  , недвижимост...  недвижимость
# 16                                 [недвижимость, \n]  недвижимость
# 17               [строительство,  , недвижимость, \n]  недвижимость
# 18  [на,  , покупка,  , подержать,  , автомобиль, \n]          авто
# 19       [на,  , покупка,  , свой,  , автомобиль, \n]          авто
# 20                                 [недвижимость, \n]  недвижимость
# 21                  [приобретение,  , автомобиль, \n]          авто
# 22  [на,  , покупка,  , подержать,  , автомобиль, \n]          авто
# 23                          [сыграть,  , свадьба, \n]       свадьба
# 24  [операция,  , с,  , коммерческий,  , недвижимо...  недвижимость
# 25                     [покупка,  , недвижимость, \n]  недвижимость
# 26                                  [образование, \n]   образование
# 27  [строительство,  , собственный,  , недвижимост...  недвижимость
# 28  [строительство,  , собственный,  , недвижимост...  недвижимость
# 29     [строительство,  , жилой,  , недвижимость, \n]  недвижимость
# 30  [операция,  , с,  , коммерческий,  , недвижимо...  недвижимость
# 31                                        [жилье, \n]  недвижимость
# 32                [на,  , проведение,  , свадьба, \n]       свадьба
# 33                            [покупка,  , жилье, \n]  недвижимость
# 34    [операция,  , со,  , свой,  , недвижимость, \n]  недвижимость
# 35                [на,  , проведение,  , свадьба, \n]       свадьба
# 36                                   [автомобиль, \n]          авто
# 37                  [приобретение,  , автомобиль, \n]          авто
# 38                                  [образование, \n]   образование
# 39                   [заниматься,  , образование, \n]   образование
# 40                     [покупка,  , недвижимость, \n]  недвижимость
# 41  [сделка,  , с,  , подержанный,  , автомобиль, \n]          авто
# 42                    [получение,  , образование, \n]   образование
# 43                  [приобретение,  , автомобиль, \n]          авто
# 44       [на,  , покупка,  , свой,  , автомобиль, \n]          авто
# 45                   [заниматься,  , образование, \n]   образование
# 46  [сделка,  , с,  , подержанный,  , автомобиль, \n]          авто
# 47                [на,  , проведение,  , свадьба, \n]       свадьба
# 48  [строительство,  , собственный,  , недвижимост...  недвижимость
# 49                                   [автомобиль, \n]          авто
#
#     dob_years_group
# 0   средний возраст
# 1   средний возраст
# 2           молодые
# 3           молодые
# 4   средний возраст
# 5           молодые
# 6   средний возраст
# 7   средний возраст
# 8           молодые
# 9   средний возраст
# 10  средний возраст
# 11  средний возраст
# 12  средний возраст
# 13  средний возраст
# 14  средний возраст
# 15          молодые
# 16          молодые
# 17          молодые
# 18  средний возраст
# 19  средний возраст
# 20  средний возраст
# 21          молодые
# 22          молодые
# 23          молодые
# 24  средний возраст
# 25       пенсионеры
# 26  средний возраст
# 27          молодые
# 28          молодые
# 29  средний возраст
# 30  средний возраст
# 31  средний возраст
# 32          молодые
# 33  средний возраст
# 34          молодые
# 35       пенсионеры
# 36          молодые
# 37  средний возраст
# 38          молодые
# 39          молодые
# 40          молодые
# 41  средний возраст
# 42          молодые
# 43  средний возраст
# 44          молодые
# 45  средний возраст
# 46  средний возраст
# 47          молодые
# 48  средний возраст
# 49  средний возраст

# %%
data['total_income'].sort_values() # смотрим разброс доходов
# Out:
# 14555      20667
# 12983      21205
# 16138      21367
# 1598       21695
# 14247      21895
#           ...
# 17137    1711309
# 20742    1715018
# 9159     1726276
# 19548    2200852
# 12390    2265604
# Name: total_income, Length: 21454, dtype: int64

# %%
def total_income_group(income): # разбиваем на категории по доходу
    if income <= 60000:
        return 'доход низкий'
    elif income <= 120000:
        return 'доход средний'
    elif income <= 180000:
        return 'доход выше среднего'
    elif income > 180000:
        return 'доход высокий'
data['total_income_group'] = data['total_income'].apply(total_income_group)
data.head(50)
# Out:
#     index  children  days_employed  dob_years            education  \
# 0       0         1    8437.673028         42               высшее
# 1       1         1    4024.803754         36              среднее
# 2       2         0    5623.422610         33              среднее
# 3       3         3    4124.747207         32              среднее
# 4       4         0  340266.072047         53              среднее
# 5       5         0     926.185831         27               высшее
# 6       6         0    2879.202052         43               высшее
# 7       7         0     152.779569         50              среднее
# 8       8         2    6929.865299         35               высшее
# 9       9         0    2188.756445         41              среднее
# 10     10         2    4171.483647         36               высшее
# 11     11         0     792.701887         40              среднее
# 12     12         0  365003.491245         65              среднее
# 13     13         0    1846.641941         54  неоконченное высшее
# 14     14         0    1844.956182         56               высшее
# 15     15         1     972.364419         26              среднее
# 16     16         0    1719.934226         35              среднее
# 17     17         0    2369.999720         33               высшее
# 18     18         0  400281.136913         53              среднее
# 19     19         0   10038.818549         48              среднее
# 20     20         1    1311.604166         36              среднее
# 21     21         1     253.685166         33              среднее
# 22     22         1    1766.644138         24              среднее
# 23     23         0     272.981385         21               высшее
# 24     24         1  338551.952911         57              среднее
# 25     25         0  363548.489348         67              среднее
# 26     26         0    3399.896902         41              среднее
# 27     27         0     529.191635         28               высшее
# 28     28         1     717.274324         26               высшее
# 29     29         0  365003.491245         63              среднее
# 30     30         1  335581.668515         62              среднее
# 31     31         0    1682.083438         47            начальное
# 32     32         0    4649.910832         34              среднее
# 33     33         0    1548.637544         48              среднее
# 34     34         0    4488.067031         35              среднее
# 35     35         0  394021.072184         68              среднее
# 36     36         0     176.216688         33              среднее
# 37     37         0    6448.810860         43               высшее
# 38     38         0     597.881827         25               высшее
# 39     39         0     650.587796         31               высшее
# 40     40         0    1030.362606         30              среднее
# 41     41         0    3399.896902         50              среднее
# 42     42         0    1257.496190         20  неоконченное высшее
# 43     43         0    4375.681384         43  неоконченное высшее
# 44     44         1    1362.041728         26              среднее
# 45     45         1    1039.451741         49              среднее
# 46     46         2    2262.712304         37              среднее
# 47     47         1    2689.137274         33               высшее
# 48     48         0    3341.067886         45              среднее
# 49     49         0    1181.443228         54              среднее
#
#     education_id          family_status  family_status_id gender  income_type  \
# 0              0        женат / замужем                 0      F    сотрудник
# 1              1        женат / замужем                 0      F    сотрудник
# 2              1        женат / замужем                 0      M    сотрудник
# 3              1        женат / замужем                 0      M    сотрудник
# 4              1       гражданский брак                 1      F    пенсионер
# 5              0       гражданский брак                 1      M    компаньон
# 6              0        женат / замужем                 0      F    компаньон
# 7              1        женат / замужем                 0      M    сотрудник
# 8              0       гражданский брак                 1      F    сотрудник
# 9              1        женат / замужем                 0      M    сотрудник
# 10             0        женат / замужем                 0      M    компаньон
# 11             1        женат / замужем                 0      F    сотрудник
# 12             1       гражданский брак                 1      M    пенсионер
# 13             2        женат / замужем                 0      F    сотрудник
# 14             0       гражданский брак                 1      F    компаньон
# 15             1        женат / замужем                 0      F    сотрудник
# 16             1        женат / замужем                 0      F    сотрудник
# 17             0       гражданский брак                 1      M    сотрудник
# 18             1         вдовец / вдова                 2      F    пенсионер
# 19             1              в разводе                 3      F    сотрудник
# 20             1        женат / замужем                 0      M    сотрудник
# 21             1       гражданский брак                 1      F    сотрудник
# 22             1       гражданский брак                 1      F    сотрудник
# 23             0       гражданский брак                 1      M    сотрудник
# 24             1  Не женат / не замужем                 4      F    пенсионер
# 25             1        женат / замужем                 0      M    пенсионер
# 26             1        женат / замужем                 0      M  госслужащий
# 27             0        женат / замужем                 0      M    сотрудник
# 28             0        женат / замужем                 0      F    сотрудник
# 29             1  Не женат / не замужем                 4      F    пенсионер
# 30             1        женат / замужем                 0      F    пенсионер
# 31             3        женат / замужем                 0      F    сотрудник
# 32             1       гражданский брак                 1      F    сотрудник
# 33             1        женат / замужем                 0      F    компаньон
# 34             1        женат / замужем                 0      F    сотрудник
# 35             1       гражданский брак                 1      M    пенсионер
# 36             1  Не женат / не замужем                 4      M    сотрудник
# 37             0       гражданский брак                 1      F    компаньон
# 38             0  Не женат / не замужем                 4      M    сотрудник
# 39             0       гражданский брак                 1      F    компаньон
# 40             1  Не женат / не замужем                 4      M    компаньон
# 41             1        женат / замужем                 0      F  госслужащий
# 42             2  Не женат / не замужем                 4      F    сотрудник
# 43             2              в разводе                 3      F    компаньон
# 44             1        женат / замужем                 0      F    сотрудник
# 45             1  Не женат / не замужем                 4      F    сотрудник
# 46             1        женат / замужем                 0      F    компаньон
# 47             0       гражданский брак                 1      M  госслужащий
# 48             1        женат / замужем                 0      F    сотрудник
# 49             1        женат / замужем                 0      F    сотрудник
#
#     debt  total_income                                 purpose  \
# 0      0        253875                           покупка жилья
# 1      0        112080                 приобретение автомобиля
# 2      0        145885                           покупка жилья
# 3      0        267628              дополнительное образование
# 4      0        158616                         сыграть свадьбу
# 5      0        255763                           покупка жилья
# 6      0        240525                       операции с жильем
# 7      0        135823                             образование
# 8      0         95856                   на проведение свадьбы
# 9      0        144425                 покупка жилья для семьи
# 10     0        113943                    покупка недвижимости
# 11     0         77069       покупка коммерческой недвижимости
# 12     0        137127                         сыграть свадьбу
# 13     0        130458                 приобретение автомобиля
# 14     1        165127              покупка жилой недвижимости
# 15     0        116820  строительство собственной недвижимости
# 16     0        289202                            недвижимость
# 17     0         90410              строительство недвижимости
# 18     0         56823      на покупку подержанного автомобиля
# 19     0        242831            на покупку своего автомобиля
# 20     0        209552                            недвижимость
# 21     0        131812                 приобретение автомобиля
# 22     0        149681      на покупку подержанного автомобиля
# 23     0        128265                         сыграть свадьбу
# 24     0        290547   операции с коммерческой недвижимостью
# 25     0         55112                    покупка недвижимости
# 26     0        170898                             образование
# 27     0        308848  строительство собственной недвижимости
# 28     0        187863  строительство собственной недвижимости
# 29     0        137127        строительство жилой недвижимости
# 30     0        171456   операции с коммерческой недвижимостью
# 31     0        275485                                   жилье
# 32     1        139057                   на проведение свадьбы
# 33     0        157245                           покупка жилья
# 34     0        104660         операции со своей недвижимостью
# 35     0         77805                   на проведение свадьбы
# 36     0        138830                              автомобили
# 37     0        154128                 приобретение автомобиля
# 38     1        192247                             образование
# 39     0        754240                   заняться образованием
# 40     0        142865                    покупка недвижимости
# 41     0        170898        сделка с подержанным автомобилем
# 42     0         82065                   получение образования
# 43     0        272957                 приобретение автомобиля
# 44     0        100780            на покупку своего автомобиля
# 45     0        106385                   заняться образованием
# 46     0        182682        сделка с подержанным автомобилем
# 47     0        356277                   на проведение свадьбы
# 48     0        162065  строительство собственной недвижимости
# 49     0         44591                              автомобиль
#
#                                        purpose_lemmas   purpose_cat  \
# 0                             [покупка,  , жилье, \n]  недвижимость
# 1                   [приобретение,  , автомобиль, \n]          авто
# 2                             [покупка,  , жилье, \n]  недвижимость
# 3                [дополнительный,  , образование, \n]   образование
# 4                           [сыграть,  , свадьба, \n]       свадьба
# 5                             [покупка,  , жилье, \n]  недвижимость
# 6                      [операция,  , с,  , жилье, \n]  недвижимость
# 7                                   [образование, \n]   образование
# 8                 [на,  , проведение,  , свадьба, \n]       свадьба
# 9           [покупка,  , жилье,  , для,  , семья, \n]  недвижимость
# 10                     [покупка,  , недвижимость, \n]  недвижимость
# 11    [покупка,  , коммерческий,  , недвижимость, \n]  недвижимость
# 12                          [сыграть,  , свадьба, \n]       свадьба
# 13                  [приобретение,  , автомобиль, \n]          авто
# 14           [покупка,  , жилой,  , недвижимость, \n]  недвижимость
# 15  [строительство,  , собственный,  , недвижимост...  недвижимость
# 16                                 [недвижимость, \n]  недвижимость
# 17               [строительство,  , недвижимость, \n]  недвижимость
# 18  [на,  , покупка,  , подержать,  , автомобиль, \n]          авто
# 19       [на,  , покупка,  , свой,  , автомобиль, \n]          авто
# 20                                 [недвижимость, \n]  недвижимость
# 21                  [приобретение,  , автомобиль, \n]          авто
# 22  [на,  , покупка,  , подержать,  , автомобиль, \n]          авто
# 23                          [сыграть,  , свадьба, \n]       свадьба
# 24  [операция,  , с,  , коммерческий,  , недвижимо...  недвижимость
# 25                     [покупка,  , недвижимость, \n]  недвижимость
# 26                                  [образование, \n]   образование
# 27  [строительство,  , собственный,  , недвижимост...  недвижимость
# 28  [строительство,  , собственный,  , недвижимост...  недвижимость
# 29     [строительство,  , жилой,  , недвижимость, \n]  недвижимость
# 30  [операция,  , с,  , коммерческий,  , недвижимо...  недвижимость
# 31                                        [жилье, \n]  недвижимость
# 32                [на,  , проведение,  , свадьба, \n]       свадьба
# 33                            [покупка,  , жилье, \n]  недвижимость
# 34    [операция,  , со,  , свой,  , недвижимость, \n]  недвижимость
# 35                [на,  , проведение,  , свадьба, \n]       свадьба
# 36                                   [автомобиль, \n]          авто
# 37                  [приобретение,  , автомобиль, \n]          авто
# 38                                  [образование, \n]   образование
# 39                   [заниматься,  , образование, \n]   образование
# 40                     [покупка,  , недвижимость, \n]  недвижимость
# 41  [сделка,  , с,  , подержанный,  , автомобиль, \n]          авто
# 42                    [получение,  , образование, \n]   образование
# 43                  [приобретение,  , автомобиль, \n]          авто
# 44       [на,  , покупка,  , свой,  , автомобиль, \n]          авто
# 45                   [заниматься,  , образование, \n]   образование
# 46  [сделка,  , с,  , подержанный,  , автомобиль, \n]          авто
# 47                [на,  , проведение,  , свадьба, \n]       свадьба
# 48  [строительство,  , собственный,  , недвижимост...  недвижимость
# 49                                   [автомобиль, \n]          авто
#
#     dob_years_group   total_income_group
# 0   средний возраст        доход высокий
# 1   средний возраст        доход средний
# 2           молодые  доход выше среднего
# 3           молодые        доход высокий
# 4   средний возраст  доход выше среднего
# 5           молодые        доход высокий
# 6   средний возраст        доход высокий
# 7   средний возраст  доход выше среднего
# 8           молодые        доход средний
# 9   средний возраст  доход выше среднего
# 10  средний возраст        доход средний
# 11  средний возраст        доход средний
# 12  средний возраст  доход выше среднего
# 13  средний возраст  доход выше среднего
# 14  средний возраст  доход выше среднего
# 15          молодые        доход средний
# 16          молодые        доход высокий
# 17          молодые        доход средний
# 18  средний возраст         доход низкий
# 19  средний возраст        доход высокий
# 20  средний возраст        доход высокий
# 21          молодые  доход выше среднего
# 22          молодые  доход выше среднего
# 23          молодые  доход выше среднего
# 24  средний возраст        доход высокий
# 25       пенсионеры         доход низкий
# 26  средний возраст  доход выше среднего
# 27          молодые        доход высокий
# 28          молодые        доход высокий
# 29  средний возраст  доход выше среднего
# 30  средний возраст  доход выше среднего
# 31  средний возраст        доход высокий
# 32          молодые  доход выше среднего
# 33  средний возраст  доход выше среднего
# 34          молодые        доход средний
# 35       пенсионеры        доход средний
# 36          молодые  доход выше среднего
# 37  средний возраст  доход выше среднего
# 38          молодые        доход высокий
# 39          молодые        доход высокий
# 40          молодые  доход выше среднего
# 41  средний возраст  доход выше среднего
# 42          молодые        доход средний
# 43  средний возраст        доход высокий
# 44          молодые        доход средний
# 45  средний возраст        доход средний
# 46  средний возраст        доход высокий
# 47          молодые        доход высокий
# 48  средний возраст  доход выше среднего
# 49  средний возраст         доход низкий

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет: Исходя из чего выбран именно такой способ категоризации столбца с доходами? Соглашусь с выбранным способом, но важно обосновать его выбор.
#
# </div>

# %% [markdown]
# **Вывод**

# %% [markdown]
# Произвели категоризацию данных по целям, возрасту и уровню дохода. Категории по возрасту и доходу искал в сети, данные разнятся, поэтому разбил на такие категории.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка: В данных есть словари. Попробуй их обнаружить и выделить. Это довольно распространенный способ хранения информации. Мне важно понять, что он тобой освоен. Заметь, что в основной таблице мы имеем по 2 параметра с образованием и семейным статусом. Именно по ним и стоит выделить словари.
#
# </div>

# %% [markdown]
# Правки по замечаниям ниже

# %%
education_cat = data.groupby(['education', 'education_id']).size().to_frame('count')
education_cat.sort_values(by='education_id')
# Out:
#                                   count
# education           education_id
# высшее              0              5250
# среднее             1             15172
# неоконченное высшее 2               744
# начальное           3               282
# ученая степень      4                 6

# %%
family_status_cat = data.groupby(['family_status', 'family_status_id']).size().to_frame('count')
family_status_cat.sort_values(by='family_status_id')
# Out:
#                                         count
# family_status         family_status_id
# женат / замужем       0                 12339
# гражданский брак      1                  4151
# вдовец / вдова        2                   959
# в разводе             3                  1195
# Не женат / не замужем 4                  2810

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Успех: Отлично, словари сделаны. Теперь мы можем убрать текстовые параметры из основной таблицы, что увеличит эффективность работы с данными.
# </div>

# %% [markdown]
# ## Шаг 3. Ответьте на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
data_pivot_children_debt = data.pivot_table(index = ['children'], values = 'debt').round(3) # сводная таблица по детям
data_pivot_children_debt.sort_values(by='debt')
# Out:
#            debt
# children
# 5         0.000
# 0         0.075
# 3         0.082
# 1         0.092
# 2         0.095
# 4         0.098

# %% [markdown]
# **Вывод**

# %% [markdown]
# Из таблицы видно, что заемщики с количеством детей от 1 до 4 возвращают долг реже, чем заемщики без детей и с 5 детьми.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Вывод не противоречит полученному результату.
#
# </div>

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
data_pivot_family_debt = data.pivot_table(index = ['family_status'], columns = 'debt', values = 'gender', aggfunc = 'count')
data_pivot_family_debt['family_debt'] = round(data_pivot_family_debt[1] / (data_pivot_family_debt[0] + data_pivot_family_debt[1]), 3)
data_pivot_family_debt.sort_values(by='family_debt') # сводная таблица по семейному положению
# Out:
# debt                       0    1  family_debt
# family_status
# вдовец / вдова           896   63        0.066
# в разводе               1110   85        0.071
# женат / замужем        11408  931        0.075
# гражданский брак        3763  388        0.093
# Не женат / не замужем   2536  274        0.098

# %% [markdown]
# **Вывод**

# %% [markdown]
# Заемщики не состоящие в официальных отношениях (Не женат / не замужем, гражданский брак) возвращают долг реже, чем остальные.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Подумай над причинами получения такого результата.
#
# </div>

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
data_pivot_income_debt = data.pivot_table(index = ['total_income_group'], columns = 'debt', values = 'gender', aggfunc = 'count')
data_pivot_income_debt['income_debt'] = round(data_pivot_income_debt[1] / (data_pivot_income_debt[0] + data_pivot_income_debt[1]), 3)
data_pivot_income_debt.sort_values(by='income_debt') # сводная таблица по уровню дохода
# Out:
# debt                    0    1  income_debt
# total_income_group
# доход низкий          757   49        0.061
# доход высокий        6416  508        0.073
# доход средний        5537  502        0.083
# доход выше среднего  7003  682        0.089

# %% [markdown]
# **Вывод**

# %% [markdown]
# Люди с низким доходом чаще стараются возвращать кредит в срок. Реже возвращают люди с высоким доходом.

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %%
data_pivot_purpose_debt = data.pivot_table(index = ['purpose_cat'], columns = 'debt', values = 'gender', aggfunc = 'count')
data_pivot_purpose_debt['purpose_debt'] = round(data_pivot_purpose_debt[1] / (data_pivot_purpose_debt[0] + data_pivot_purpose_debt[1]), 3)
data_pivot_purpose_debt.sort_values(by='purpose_debt') # сводная таблица по цели кредита
# Out:
# debt              0    1  purpose_debt
# purpose_cat
# недвижимость  10029  782         0.072
# свадьба        2138  186         0.080
# образование    3643  370         0.092
# авто           3903  403         0.094

# %% [markdown]
# **Вывод**

# %% [markdown]
# Люди, берущие кредит на недвижимость, возвращают долг чаще, чем люди, берущие кредит, на образование или авто.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Здорово, что при анализе использован метод сводных таблиц. Он пригодится в дальнейших проектах.
#
# Выводы сделаны по всем пунктам.
#
# </div>

# %% [markdown]
# ## Шаг 4. Общий вывод

# %% [markdown]
# Идеальный заемщик: человек с 5-ю детьми, овдовевший, с низким уровнем дохода, берущий кредит на недвижимость.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ошибка: Финальный вывод и есть главный результат твоей работы. Стоит писать его подробно по результатам проведенной работы. В нем можно приводить полученные в ходе работы значения. Также можно расписать все, что было сделано в работе.
#
# </div>

# %% [markdown]
# <div>
# <font size="3"><b>Вывод</b></font>
#
# В ходе исследования мы изучили датафрейм, выявили ошибки и пропуски. Исправили и заполнили средними значениями по категориям.
#
# Выявили и удалили дубликаты. Произвели лемматизацию и категоризацию данных.
#
# В ходе исследования выявили зависимость между наличием детей и возвратом кредита в срок.
# Заемщики с 5-ю детьми не имеют задолжностей. Заемщики без детей возвращаю кредиты чаще, чем заемщики с 1-4 детьми.
#
# Также выяснили, что овдовевшие заемщики платят чаще, чем люди не имеющие официальных отношений.
#
# Выявили зависимость между уровнем дохода и возвратом кредита в срок. Заемщики с низким и высоким доходом более ответственные,
# чем заемщики со средним доходом и доходом выше среднего.
#
# Также на возват кредита в срок влияют и цели кредита. Кредит на недвижимость и свадьбу возвращают чаще, чем кредит на
#     образование и автомобиль.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех: Выводы описаны грамотно. Приведены ответы на главные вопросы проекта. В выводах можно приводить полученные ранее значения, правильно. Здорово, что по каждому пункту работы приведен вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Ты проделал большую работу, молодец! Ты овладел важными на данном этапе обучения инструментами, а также довольно качественно их используешь. Критических замечаний немного. Однако их важно исправить. Также есть несколько желтых комментариев. Думаю, исправить и их тебе не составит труда. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Помарки исправлены, и теперь работа выполнена хорошо. Ты здорово поработал, молодец. Продолжай в том же духе! Успехов в дальнейших проектах :)
#
# С наступающими праздниками!
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл;
# - [x]  файл изучен;
# - [x]  определены пропущенные значения;
# - [x]  заполнены пропущенные значения;
# - [x]  есть пояснение, какие пропущенные значения обнаружены;
# - [x]  описаны возможные причины появления пропусков в данных;
# - [x]  объяснено, по какому принципу заполнены пропуски;
# - [x]  заменен вещественный тип данных на целочисленный;
# - [x]  есть пояснение, какой метод используется для изменения типа данных и почему;
# - [x]  удалены дубликаты;
# - [x]  есть пояснение, какой метод используется для поиска и удаления дубликатов;
# - [x]  описаны возможные причины появления дубликатов в данных;
# - [x]  выделены леммы в значениях столбца с целями получения кредита;
# - [x]  описан процесс лемматизации;
# - [x]  данные категоризированы;
# - [x]  есть объяснение принципа категоризации данных;
# - [x]  есть ответ на вопрос: "Есть ли зависимость между наличием детей и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между семейным положением и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между уровнем дохода и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Как разные цели кредита влияют на его возврат в срок?";
# - [x]  в каждом этапе есть выводы;
# - [x]  есть общий вывод.
